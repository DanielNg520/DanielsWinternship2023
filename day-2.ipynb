# %% [markdown]
# # Day 2

# %% [markdown]
# ## Data Basics

# %% [markdown]
# ### Lists
#
# Often, we have many measurements for a single metric. For instance, suppose we measure the speed(mph) of a car moving on the highway at one minute intervals. We do not want to store all of those measurements in a series of variables. We can store a `list` of values in a single variable.

# %%
speed = [56, 61, 62, 66, 67, 68, 69, 76, 77, 78]

# %% [markdown]
# With this list, we can extract information about the car.
#
# Is it accelerating or decelerating?
#
# What is its average speed over the period of observation?
#
# What might the next measurement in this list be?

# %%
# demo
increasing = False
for i in range(1, len(speed)):
    if speed[i-1] < speed[i]:
        increasing = True
    else:
        increasing = False
        break

print(f"increasing: {increasing}")

decreasing = False
for i in range(1, len(speed)):
    if speed[i-1] > speed[i]:
        decreasing = True
    else:
        decreasing = False
        break

print(f"decreasing: {decreasing}")

avg = 0
for measurement in speed:
    avg += measurement
avg /= len(speed)

print(f"average speed: {avg}")


avg_diff = 0
for i in range(1, len(speed)):
    avg_diff += speed[i] - speed[i-1]
avg_diff /= (len(speed) - 1)

print(f"average difference between measurements in speed: {avg_diff}")
print(f"extrapolated speed measurement at t=11: {speed[-1] + avg_diff}")
# Out:
# increasing: True
# decreasing: False
# average speed: 68.0
# average difference between measurements in speed: 2.4444444444444446
# extrapolated speed measurement at t=11: 80.44444444444444

# %% [markdown]
# Sometimes we want to take parts of the data, we can use slices to do this.

# %%
print(speed[0:5])
print(speed[2:7])
print(speed[-3:])
# Out:
# [56, 61, 62, 66, 67]
# [62, 66, 67, 68, 69]
# [76, 77, 78]

# %% [markdown]
# More often than not, we will be working with data that has more than one dimension.

# %%
# each sublist represents 
# when the measurement was taken and the measurement itself
# the first sublist says the measurement is 56mph at t=0
speed = [[0, 56], [1, 61], [2, 62], [3, 66], [4, 67],
         [5, 68], [6, 69], [7, 76], [8, 77], [9, 78]]

import matplotlib.pyplot as plt
# example of list comprehention to format data
plt.scatter(
    [sublist[0] for sublist in speed], 
    [sublist[1] for sublist in speed]
)

# %% [markdown]
# Thankfully, we have libraries to make handling large data easier.
#
# https://pandas.pydata.org
#
# https://pandas.pydata.org/docs/reference/plotting.html

# %%
import pandas as pd

# retrieved from https://data.noaa.gov/datasetsearch/
data = pd.read_csv("./data.csv", header=1)
print(data.columns)
data['datetime'] = pd.to_datetime(data['Date'])
data.drop('Date', axis=1, inplace=True)
data = data.set_index('datetime')
print(data.columns)
data.columns = ['TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW', 'SNWD']
print(data.columns)
data.head()
# Out:
# Index(['Date', 'TAVG (Degrees Fahrenheit)', 'TMAX (Degrees Fahrenheit)',
#        'TMIN (Degrees Fahrenheit)', 'PRCP (Inches)', 'SNOW (Inches)',
#        'SNWD (Inches)'],
#       dtype='object')
# Index(['TAVG (Degrees Fahrenheit)', 'TMAX (Degrees Fahrenheit)',
#        'TMIN (Degrees Fahrenheit)', 'PRCP (Inches)', 'SNOW (Inches)',
#        'SNWD (Inches)'],
#       dtype='object')
# Index(['TAVG', 'TMAX', 'TMIN', 'PRCP', 'SNOW', 'SNWD'], dtype='object')
#             TAVG  TMAX  TMIN  PRCP  SNOW  SNWD
# datetime
# 1909-12-01   NaN   NaN   NaN   0.0   0.0   NaN
# 1909-12-02   NaN   NaN   NaN   0.0   0.0   NaN
# 1909-12-03   NaN   NaN   NaN   0.0   0.0   NaN
# 1909-12-04   NaN   NaN   NaN   0.0   0.0   NaN
# 1909-12-05   NaN   NaN   NaN   0.0   0.0   NaN

# %%
data[data.index.year == 2000].describe()
# Out:
#        TAVG        TMAX        TMIN        PRCP   SNOW   SNWD
# count   0.0  330.000000  337.000000  363.000000  363.0  360.0
# mean    NaN   89.430303   61.451039    0.005647    0.0    0.0
# std     NaN   15.552333   13.259705    0.038412    0.0    0.0
# min     NaN   60.000000   36.000000    0.000000    0.0    0.0
# 25%     NaN   76.000000   50.000000    0.000000    0.0    0.0
# 50%     NaN   89.000000   61.000000    0.000000    0.0    0.0
# 75%     NaN  103.000000   72.000000    0.000000    0.0    0.0
# max     NaN  118.000000   92.000000    0.440000    0.0    0.0

# %%
max_temp_2000 = data[data.index.year == 2000].TMAX.dropna()
print(max_temp_2000.describe())
max_temp_2000.plot()
import matplotlib.pyplot as plt
x = data[data.index.year == 2000].index
y1 = data[data.index.year == 2000].TMAX
y2 = data[data.index.year == 2001].TMAX
plt.plot(x, y1)
plt.plot(x, y2)
# Out:
# count    330.000000
# mean      89.430303
# std       15.552333
# min       60.000000
# 25%       76.000000
# 50%       89.000000
# 75%      103.000000
# max      118.000000
# Name: TMAX, dtype: float64

# %%
y1 = data[data.index.year == 2000].TMAX
y2 = data[data.index.year == 2001].TMAX
plt.plot(range(364), y1)
plt.plot(range(364), y2)

# %%
x = data[data.index.year == 2000].index.shape[0]
y1 = data[data.index.year == 1995].TMAX
print(y1.shape)
y2 = data[data.index.year == 2001].TMAX
print(y2.shape)
y2 = data[(data.index.year == 2001) & (data.index.month == 5)].TMAX
print(y2)
# Out:
# (365,)
# (364,)
# datetime
# 2001-05-02     89.0
# 2001-05-03     86.0
# 2001-05-04     91.0
# 2001-05-05     93.0
# 2001-05-06     95.0
# 2001-05-07    104.0
# 2001-05-08    109.0
# 2001-05-09    111.0
# 2001-05-10    111.0
# 2001-05-11    103.0
# 2001-05-12    102.0
# 2001-05-13     97.0
# 2001-05-14     98.0
# 2001-05-15     97.0
# 2001-05-16    102.0
# 2001-05-17    102.0
# 2001-05-18    102.0
# 2001-05-19     99.0
# 2001-05-20    106.0
# 2001-05-21    112.0
# 2001-05-22    110.0
# 2001-05-23    116.0
# 2001-05-24    112.0
# 2001-05-25    111.0
# 2001-05-26    109.0
# 2001-05-27    107.0
# 2001-05-28     89.0
# 2001-05-29     98.0
# 2001-05-30    103.0
# 2001-05-31    113.0
# Name: TMAX, dtype: float64

# %%
#https://stackoverflow.com/questions/1060279/iterating-through-a-range-of-dates-in-python
from datetime import date, timedelta

start_date = "1909-12-01"
end_date = "2010-12-31"

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2013, 1, 1)
end_date = date(2015, 6, 2)
for single_date in daterange(start_date, end_date):
    print(single_date.strftime("%Y-%m-%d"))
# Out:
# 2013-01-01
# 2013-01-02
# 2013-01-03
# 2013-01-04
# 2013-01-05
# 2013-01-06
# 2013-01-07
# 2013-01-08
# 2013-01-09
# 2013-01-10
# 2013-01-11
# 2013-01-12
# 2013-01-13
# 2013-01-14
# 2013-01-15
# 2015-01-15
# 2015-01-16
# 2015-01-17
# 2015-01-18
# 2015-01-19
# 2015-01-20
# 2015-01-21
# 2015-01-22
# 2015-01-23
# 2015-01-24
# 2015-01-25
# 2015-01-26
# 2015-01-27
# 2015-01-28
# 2015-01-29
# 2015-01-30
# 2015-01-31
# 2015-02-01
# 2015-02-02
# 2015-02-03
# 2015-02-04
# 2015-02-05
# 2015-02-06
# 2015-02-07
# 2015-02-08
# 2015-02-09
# 2015-02-10
# 2015-02-11
# 2015-02-12
# 2015-02-13
# 2015-02-14
# 2015-02-15
# 2015-02-16
# 2015-02-17
# 2015-02-18
# 2015-02-19
# 2015-02-20
# 2015-02-21
# 2015-02-22
# 2015-02-23
# 2015-02-24
# 2015-02-25
# 2015-02-26
# 2015-02-27
# 2015-02-28
# 2015-03-01
# 2015-03-02
# 2015-03-03
# 2015-03-04
# 2015-03-05
# 2015-03-06
# 2015-03-07
# 2015-03-08
# 2015-03-09
# 2015-03-10
# 2015-03-11
# 2015-03-12
# 2015-03-13
# 2015-03-14
# 2015-03-15
# 2015-03-16
# 2015-03-17
# 2015-03-18
# 2015-03-19
# 2015-03-20
# 2015-03-21
# 2015-03-22
# 2015-03-23
# 2015-03-24
# 2015-03-25
# 2015-03-26
# 2015-03-27
# 2015-03-28
# 2015-03-29
# 2015-03-30
# 2015-03-31
# 2015-04-01
# 2015-04-02
# 2015-04-03
# 2015-04-04
# 2015-04-05
# 2015-04-06
# 2015-04-07
# 2015-04-08
# 2015-04-09
# 2015-04-10
# 2015-04-11
# 2015-04-12
# 2015-04-13
# 2015-04-14
# 2015-04-15
# 2015-04-16
# 2015-04-17
# 2015-04-18
# 2015-04-19
# 2015-04-20
# 2015-04-21
# 2015-04-22
# 2015-04-23
# 2015-04-24
# 2015-04-25
# 2015-04-26
# 2015-04-27
# 2015-04-28
# 2015-04-29
# 2015-04-30
# 2015-05-01
# 2015-05-02
# 2015-05-03
# 2015-05-04
# 2015-05-05
# 2015-05-06
# 2015-05-07
# 2015-05-08
# 2015-05-09
# 2015-05-10
# 2015-05-11
# 2015-05-12
# 2015-05-13
# 2015-05-14
# 2015-05-15
# 2015-05-16
# 2015-05-17
# 2015-05-18
# 2015-05-19
# 2015-05-20
# 2015-05-21
# 2015-05-22
# 2015-05-23
# 2015-05-24
# 2015-05-25
# 2015-05-26
# 2015-05-27
# 2015-05-28
# 2015-05-29
# 2015-05-30
# 2015-05-31
# 2015-06-01

# %%
data.head()
dataframe = pd.DataFrame()
dataframe.to_csv('/data_modified.csv')
#pd.dataframe.iloc
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-27-f7a8faceaed6> in <module>
#       1 data.head()
#       2 dataframe = pd.DataFrame()
# ----> 3 dataframe.to_csv('/data_modified.csv')
#       4 #pd.dataframe.iloc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# OSError: [Errno 30] Read-only file system: '/data_modified.csv'
